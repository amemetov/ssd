# %%
import numpy as np
import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

import imaging

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
img = imaging.load_img('../datasets/voc2012/VOCtrainval_11-May-2012/JPEGImages/2007_000032.jpg')
img_float = img.astype(np.float32)
plt.imshow(img)

# %%
bright = imaging.randomize_brightness(img_float)
plt.imshow(bright.astype(np.uint8))

# %%
contrast = imaging.randomize_contrast(img_float)
plt.imshow(contrast.astype(np.uint8))

# %%
hue = imaging.randomize_hue(img_float)
plt.imshow(hue.astype(np.uint8))

# %%
saturation = imaging.randomize_saturation(img_float)
plt.imshow(saturation.astype(np.uint8))
